# %%
from pynxtools.dataconverter.template import Template
from pynxtools.dataconverter.helpers import generate_template_from_nxdl, get_nxdl_root_and_path 

template = Template()

app_def = "NXstm"
root, nxdl_path = get_nxdl_root_and_path(app_def)
generate_template_from_nxdl(root, nxdl_name=app_def, template=template)

def transfer_plain_template_to_nested_dict(template, nested_dict):
    """TODO: Write a doc compatibel with doc test write test in pytest."""

    def split_each_key(key, final_val, nested_dict):
        parts = key.split("/", 1)
        if len(parts) < 2:
            parts.append("")
        k1, rest = parts
        k1_val = nested_dict.get(k1, None)
        if k1_val is None and rest != "":
            nested_dict[k1] = dict()
            split_each_key(rest, final_val, nested_dict[k1])
        elif rest == "":
            nested_dict[k1] = final_val
        elif isinstance(k1_val, dict):
            split_each_key(rest, final_val, k1_val)

    for key, value in template.items():
        parts, rest = key.split("/", 1)
        split_each_key(key=rest, final_val=value, nested_dict=nested_dict)

# %%
NXspm = {
    "/ENTRY[entry]/experiment_instrument/scan_environment/stm_head_temp": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/stm_head_temp/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_bottom_temp": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_bottom_temp/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temp": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temp/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_angle_N[scan_angle_n]": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_angle_N[scan_angle_n]/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_speed": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_speed/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_time": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_time/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/forward_speed_N[forward_speed_n]": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/forward_speed_N[forward_speed_n]/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/backward_speed_N[backward_speed_n]": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/backward_speed_N[backward_speed_n]/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/value": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/calibration_time": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/value/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/value": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/calibration_time": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/value/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/value": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/calibration_time": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/value/@units": None,
    "/ENTRY[entry]/experiment_instrument/tip_temperature": None,
    "/ENTRY[entry]/experiment_instrument/tip_temperature/temperature/@units": None,
    "/ENTRY[entry]/experiment_instrument/tip_temperature/temperature": None,
    "/ENTRY[entry]/experiment_instrument/cryo_temperature": None,
    "/ENTRY[entry]/experiment_instrument/cryo_temperature/temperature/@units": None,
    "/ENTRY[entry]/experiment_instrument/cryo_temperature/temperature": None,
    "/ENTRY[entry]/experiment_instrument/cryo_shield_temperature": None,
    "/ENTRY[entry]/experiment_instrument/cryo_shield_temperature/temperature/@units": None,
    "/ENTRY[entry]/experiment_instrument/cryo_shield_temperature/temperature": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_offset": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_offset/@units": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/caliberation_time": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/caliberation_time/@units": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/coefficients": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/coefficients/@units": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/linear_sweep/step_size_bias/@units": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_end_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_range_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/settling_time/@units": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_offset_bias/@units": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_start_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/settling_time": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_end_bias/@units": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/linear_sweep/step_size_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/linear_sweep/reset_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_offset_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/linear_sweep/scan_points_bias": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_range_bias/@units": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/BIAS_SPECTROSCOPY[bias_spectroscopy]/bias_sweep/scan_region/scan_start_bias/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/drift_correction_status": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/tip_lift": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/tip_lift/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/switch_off_delay": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/switch_off_delay/@units": None,
    "/ENTRY[entry]/reproducibility_indicators/current": None,
    "/ENTRY[entry]/reproducibility_indicators/current_offset": None,
    "/ENTRY[entry]/reproducibility_indicators/current_gain": None,
    "/ENTRY[entry]/reproducibility_indicators/bias_sweep": None,
    "/ENTRY[entry]/reproducibility_indicators/modulation_signal_type": None,
    "/ENTRY[entry]/reproducibility_indicators/modulation_frequency": None,
    "/ENTRY[entry]/resolution_indicators/modulation_signal_type": None,
    "/ENTRY[entry]/resolution_indicators/modulation_frequency": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/controller_name": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/controller_status": None,
    "/ENTRY[entry]/definition": None,
    "/ENTRY[entry]/definition/@version": None,
    "/ENTRY[entry]/scan_mode": None,
    "/ENTRY[entry]/experiment_instrument/LOCKIN[lockin]/modulation_signal_type": None,
    "/ENTRY[entry]/experiment_instrument/LOCKIN[lockin]/modulation_frequency": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_type": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_range": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_range/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset/@units": None,
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/SCAN_DATA[scan_data]": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/current/@units": None,
    "/ENTRY[entry]/experiment_instrument/current_sensor/AMPLIFIER[amplifier]/current_gain": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/measurement_sensors": None,
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/independent_controllers": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/x": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/x/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/y": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/y/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/z": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/z/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/2nd_order_corr_N[2nd_order_corr_n]": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/2nd_order_corr_N[2nd_order_corr_n]/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_type": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_coeffecient_N[calibration_coeffecient_n]": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_coeffecient_N[calibration_coeffecient_n]/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/drift_N[drift_n]": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/tilt_N[tilt_n]": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/tilt_N[tilt_n]/@units": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/hv_gain_N[hv_gain_n]": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/z": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/set_point": None,
    "/ENTRY[entry]/experiment_instrument/piazo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/set_point/@units": None,
    "/ENTRY[entry]/resolution_indicators/stm_head_temp": None,
    "/ENTRY[entry]/resolution_indicators/cryo_bottom_temp": None,
    "/ENTRY[entry]/resolution_indicators/cryo_shield_temp": None,
    "/ENTRY[entry]/resolution_indicators/bias_sweep": None,
}
Nested_SPM = {}
transfer_plain_template_to_nested_dict(template, Nested_SPM)

# %%
Nested_SPM = {'ENTRY[entry]': {'definition': {'@version': None},
  'experiment_instrument': {'LOCKIN[lockin]': {'modulation_frequency': None,
    'modulation_signal_type': None},
   'bias_spectroscopy_environment': {'BIAS_SPECTROSCOPY[bias_spectroscopy]': None,
    'independent_controllers': None,
    'measurement_sensors': None},
   'cryo_shield_temperature': {'temperature': {'@units': None}},
   'cryo_temperature': {'temperature': {'@units': None}},
   'current_sensor': {'AMPLIFIER[amplifier]': {'current_gain': None},
    'current': {'@units': None},
    'current_calibration': {'caliberation_time': {'@units': None},
     'coefficients': {'@units': None}},
    'current_offset': {'@units': None}},
   'piazo_sensor': {'PIEZO_CONFIG_SPM[piezo_config_spm]': {'2nd_order_corr_N[2nd_order_corr_n]': {'@units': None},
     'calibration_coeffecient_N[calibration_coeffecient_n]': {'@units': None},
     'calibration_type': None,
     'drift_N[drift_n]': None,
     'drift_correction_status': None,
     'hv_gain_N[hv_gain_n]': None,
     'tilt_N[tilt_n]': {'@units': None}},
    'POSITIONER_SPM[positioner_spm]': {'z_controller': {'controller_name': None,
      'controller_status': None,
      'set_point': {'@units': None},
      'switch_off_delay': {'@units': None},
      'tip_lift': {'@units': None},
      'z': None}},
    'x': {'@units': None},
    'y': {'@units': None},
    'z': {'@units': None}},
   'scan_environment': {'SCAN_CONTROL[scan_control]': {'mesh_SCAN[mesh_scan]': {'SCAN_DATA[scan_data]': None,
      'backward_speed_N[backward_speed_n]': {'@units': None},
      'forward_speed_N[forward_speed_n]': {'@units': None},
      'scan_speed': {'@units': None},
      'scan_time': {'@units': None}},
     'scan_region': {'scan_angle_N[scan_angle_n]': {'@units': None},
      'scan_offset': {'@units': None},
      'scan_range': {'@units': None}},
     'scan_type': None},
    'cryo_bottom_temp': {'@units': None},
    'cryo_shield_temp': {'@units': None},
    'cryo_shield_temperature': {'calibration_time': None,
     'value': {'@units': None}},
    'cryo_temperature': {'calibration_time': None, 'value': {'@units': None}},
    'stm_head_temp': {'@units': None},
    'tip_temperature': {'calibration_time': None, 'value': {'@units': None}}},
   'tip_temperature': {'temperature': {'@units': None}}},
  'reproducibility_indicators': {'bias_sweep': None,
   'current': None,
   'current_gain': None,
   'current_offset': None,
   'modulation_frequency': None,
   'modulation_signal_type': None},
  'resolution_indicators': {'bias_sweep': None,
   'cryo_bottom_temp': None,
   'cryo_shield_temp': None,
   'modulation_frequency': None,
   'modulation_signal_type': None,
   'stm_head_temp': None}
   }}
# Out:
# 262144

# %%
{
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/sweep_control/circuit/signals_oversampling": "/NanonisMain/Signals Oversampling/value",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/recorded_channels": "@eln",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/status": "/Lock-in/Lock-in status/value",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/run": "/Bias Spectroscopy/Lock-In run/value",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/hardware": "@eln",
    "/ENTRY[entry]/INSTRUMENT[instrument]/software": "@eln",
    "/ENTRY[entry]/definition": "@eln",
    "/ENTRY[entry]/experiment_description": "@eln",
    "/ENTRY[entry]/DATA[data]": [
        {"data": {"name": "",
                  "raw_path": "",
                  "@units": ""},
         "0":{"name": "",
              "raw_path": "",
              "@units": ""},
         "title":"",
        "grp_name": ""},
        {"data": {"name": "",
                  "raw_path": "",
                  "@units": ""},
         "0":{"name": "",
              "raw_path": "",
              "@units": ""},
         "title":"",
         ""}
    ]
    
                                   "/dat_mat_components/Temperature 1/value",
                                   "/dat_mat_components/Temperature 1/unit",
                              "2": ["/dat_mat_components/Bias [filt]/value",
                                   "/dat_mat_components/Bias [filt]/unit",
                                   "dat_mat_components/Bias [filt]/metadata",
                                   "/dat_mat_components/Temperature 1 [filt]/value",
                                   "/dat_mat_components/Temperature 1 [filt]/unit",
                                   "/dat_mat_components/Temperature 1 [filt]/metadata",
}
