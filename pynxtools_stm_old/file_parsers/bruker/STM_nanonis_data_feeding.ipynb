# %%
from typing import Dict, Any
import json

# %%
(-2.354637E-7 , -2.354637E-7 +  5.000000E-9 ), (1.267476E-7, 1.267476E-7 + 1.267476E-7)
# Out:
# ((-2.354637e-07, -2.304637e-07), (1.267476e-07, 2.534952e-07))

# %%
revious_config =  {"/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/position/x": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/position/x/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/position/y": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/position/y/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/position/z": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/position/z/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/scan_control/roi/frame": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/cryo_bottom_temp": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/cryo_bottom_temp/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_amplifier": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/hardware": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/recorded_channels": "@eln",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/run": "check",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/hardware": "@eln",
    "/ENTRY[entry]/INSTRUMENT[instrument]/lock_in/software": "@eln",
    "/ENTRY[entry]/INSTRUMENT[instrument]/output_cabling": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/software": "@eln",
    "/ENTRY[entry]/alternative_plot": "None",
    "/ENTRY[entry]/definition": "@eln",
    "/ENTRY[entry]/entry_identifier": "None",
    "/ENTRY[entry]/line_scan": "None",
    "/ENTRY[entry]/mesh_scan": "None",
    "/ENTRY[entry]/reproducibility_indicators/1st_settling_time": "None",
    "/ENTRY[entry]/reproducibility_indicators/backward_sweep": "None",
    "/ENTRY[entry]/reproducibility_indicators/bias": "None",
    "/ENTRY[entry]/reproducibility_indicators/bias_calibration": "None",
    "/ENTRY[entry]/reproducibility_indicators/bias_offset": "None",
    "/ENTRY[entry]/reproducibility_indicators/current": "None",
    "/ENTRY[entry]/reproducibility_indicators/current_calibration": "None",
    "/ENTRY[entry]/reproducibility_indicators/current_gain": "None",
    "/ENTRY[entry]/reproducibility_indicators/current_offset": "None",
    "/ENTRY[entry]/reproducibility_indicators/end_settling_time": "None",
    "/ENTRY[entry]/reproducibility_indicators/final_z": "None",
    "/ENTRY[entry]/reproducibility_indicators/integration_time": "None",
    "/ENTRY[entry]/reproducibility_indicators/max_slew_rate": "None",
    "/ENTRY[entry]/reproducibility_indicators/program": "None",
    "/ENTRY[entry]/reproducibility_indicators/settling_time": "None",
    "/ENTRY[entry]/reproducibility_indicators/start_time": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_contro_time": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_hold": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_i_gain": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_name": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_p_gain": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_status": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_switchoff_delay": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_time_const": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_control_tip_lift": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_offset": "None",
    "/ENTRY[entry]/reproducibility_indicators/z_sontrol_setpoint": "None",
    "/ENTRY[entry]/resolution_indicators/acquisition_period": "None",
    "/ENTRY[entry]/resolution_indicators/animation_period": "None",
    "/ENTRY[entry]/resolution_indicators/indicators_period": "None",
    "/ENTRY[entry]/resolution_indicators/integration_time": "None",
    "/ENTRY[entry]/resolution_indicators/measurement_period": "None",
    "/ENTRY[entry]/resolution_indicators/modulated_signal_bias": "None",
    "/ENTRY[entry]/resolution_indicators/number_of_pixels": "None",
    "/ENTRY[entry]/resolution_indicators/number_of_sweps": "None",
    "/ENTRY[entry]/resolution_indicators/oversampling": "None",
    "/ENTRY[entry]/resolution_indicators/program": "None",
    "/ENTRY[entry]/resolution_indicators/rt_freq": "None",
    "/ENTRY[entry]/resolution_indicators/sweep_end": "None",
    "/ENTRY[entry]/resolution_indicators/sweep_start": "None",
    "/ENTRY[entry]/resolution_indicators/temp_cryo_bottom": "None",
    "/ENTRY[entry]/resolution_indicators/temp_cryo_shield": "None",
    "/ENTRY[entry]/resolution_indicators/temp_stm_head": "None",
    "/ENTRY[entry]/resolution_indicators/z_avg_time": "None",
    "/ENTRY[entry]/single_point": "None",
    "/ENTRY[entry]/type": "@eln",
    "unit_of_x_y_coordinate": "/Z-Controller/Z/@unit"
}
stm_nanonis_data_feeding = {
    # "/@HDF5_Version[@hdf5_version]": "",
    # "/@HDF_version[@hdf_version]": "",
    # "/@NX_class[@nx_class]": "",
    # "/@NeXus_repository[@nexus_repository]": "",
    # "/@NeXus_version[@nexus_version]": "",
    # "/@XML_version[@xml_version]": "",
    # "/@creator": "",
    # "/@creator_version": "",
    # "/@default": "",
    # "/@file_name": "",
    # "/@file_time": "",
    # "/@file_update_time": "",
    # "/@h5py_version": "",
    # "/@partial": "",
    # TODO: Try to create NXclass-wise config
    # TODO: rename instrument -> experiment_instrument in NXstm
    
    ##### instrument
    "/ENTRY[entry]/experiment_instrument/tip_temperature": "", # note: grp NXsensor, not found
    "/ENTRY[entry]/experiment_instrument/cryo_temperature": "", # note: grp NXsensor, not found
    "/ENTRY[entry]/experiment_instrument/cryo_shield_temperature": "", # note: grp NXsensor, not found

    #### scan_environment
    "/ENTRY[entry]/experiment_instrument/scan_environment/stm_head_temp": {"raw_path":"/Temperature 1/Temperature 1",
                                                                           "@units": "",}
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_bottom_temp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_bottom_temp/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temp/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/backward_speed_N[backward_speed_n]": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/backward_speed_N[backward_speed_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/forward_speed_N[forward_speed_n]": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/forward_speed_N[forward_speed_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_speed_N[scan_speed_n]": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_speed_N[scan_speed_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/channel_NAME_N[scan_name_n]": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/channel_NAME_N[scan_name_n]/@units": "",
    
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_points_N[scan_points_n]": {"raw_path": "/SCAN/PIXELS"},
    # "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_points_N[scan_points_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/stepping_N[stepping_n]": {"raw_path": "@default:1",},
    # "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/stepping_N[stepping_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/step_size_N[step_size_n]": {"raw_path": "",
                                                                                                                                      "@units": "",},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_time": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_time/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/SCAN_DATA[scan_data]": {"raw_path": "/DATA/INFO"},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_angle_N[scan_angle_n]": {"raw_path": "/SCAN/ANGLE",
                                                                                                                               "@units": "@default:deg"},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset_N[scan_offset_n]": {"raw_path": "/SCAN/OFFSET",
                                                                                                                                 "@units": ""},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_range_N[scan_range_n]": {"raw_path": "/SCAN/RANGE",
                                                                                                                               "@units": "",},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_time_start": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_time_end": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/independent_scan_axes": {"raw_path": "/SCAN/DIR",},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_resolution_N": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/accuracy_N": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_type": {"raw_path":"@default:mesh",},
    "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_control_type": {"raw_path": "@default:continuous"},
    ####
    #####
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/run_control": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/run_control/@description": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/value": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/value/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/value_timestamp": "",
    
    "/ENTRY[entry]/experiment_instrument/scan_environment/independent_controllers": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/measurement_sensors": "",
    "/ENTRY[entry]/experiment_instrument/LOCKIN[lockin]/modulation_frequency": "",
    "/ENTRY[entry]/experiment_instrument/LOCKIN[lockin]/modulation_frequency/@units": "",
    "/ENTRY[entry]/experiment_instrument/LOCKIN[lockin]/modulation_signal_type": "",
    "/ENTRY[entry]/experiment_instrument/LOCKIN[lockin]/modulation_signal_type/@units": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/SENSOR[sensor]/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/SENSOR[sensor]/run_control": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/SENSOR[sensor]/run_control/@description": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/SENSOR[sensor]/value": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/SENSOR[sensor]/value/@units": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/SENSOR[sensor]/value_timestamp": "",
    
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/independent_controllers": "",
    "/ENTRY[entry]/experiment_instrument/bias_spectroscopy_environment/measurement_sensors": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/AMPLIFIER[amplifier]/current_gain": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/AMPLIFIER[amplifier]/current_gain/@units": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current/@units": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/calibration_time/@units": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/coefficients": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_calibration/coefficients/@units": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_offset": "",
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_offset/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/2nd_order_corr_N[2nd_order_corr_n]": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/2nd_order_corr_N[2nd_order_corr_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_coeffecient_N[calibration_coeffecient_n]": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_coeffecient_N[calibration_coeffecient_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_type": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/drift_N[drift_n]": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/drift_correction_status": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/hv_gain_N[hv_gain_n]": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/tilt_N[tilt_n]": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/tilt_N[tilt_n]/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/controller_name": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/controller_status": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/i_gain": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/i_gain/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/p_gain": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/p_gain/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/set_point": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/set_point/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/switch_off_delay": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/switch_off_delay/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/time_const": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/time_const/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/tip_lift": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/tip_lift/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/z": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/x": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/x/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/y": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/y/@units": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/z": "",
    "/ENTRY[entry]/experiment_instrument/piezo_sensor/z/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/run_control": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/run_control/@description": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/value": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/value/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/SENSOR[sensor]/value_timestamp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_bottom_temp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_bottom_temp/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temp/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/run_control": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/run_control/@description": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/value": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/value/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_shield_temperature/value_timestamp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/run_control": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/run_control/@description": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/value": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/value/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/cryo_temperature/value_timestamp": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/independent_controllers": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/measurement_sensors": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/calibration_time": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/run_control": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/run_control/@description": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/value": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/value/@units": "",
    "/ENTRY[entry]/experiment_instrument/scan_environment/tip_temperature/value_timestamp": "",
    "/ENTRY[entry]/PROCESS[process]/program": "",
    "/ENTRY[entry]/PROCESS[process]/program/@program_url": "",
    "/ENTRY[entry]/PROCESS[process]/program/@version": "",
    "/ENTRY[entry]/SAMPLE[sample]/name": "",
    "/ENTRY[entry]/USER[user]/address": "",
    "/ENTRY[entry]/USER[user]/affiliation": "",
    "/ENTRY[entry]/USER[user]/email": "",
    "/ENTRY[entry]/USER[user]/name": "",
    "/ENTRY[entry]/USER[user]/orcid": "",
    "/ENTRY[entry]/USER[user]/telephone_number": "",
    "/ENTRY[entry]/collection_identifier": "",
    "/ENTRY[entry]/definition": "",
    "/ENTRY[entry]/definition/@version": "",
    "/ENTRY[entry]/end_time": "",
    "/ENTRY[entry]/end_time/@units": "",
    "/ENTRY[entry]/entry_identifier": "",
    "/ENTRY[entry]/experiment_description": "",
    "/ENTRY[entry]/experiment_identifier": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/SENSOR[sensor]/calibration_time": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/SENSOR[sensor]/run_control": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/SENSOR[sensor]/run_control/@description": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/SENSOR[sensor]/value": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/SENSOR[sensor]/value/@units": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/SENSOR[sensor]/value_timestamp": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/current_sensor/calibration_time": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/current_sensor/run_control": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/current_sensor/run_control/@description": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/current_sensor/value": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/current_sensor/value/@units": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/current_sensor/value_timestamp": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/independent_controllers": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/measurement_sensors": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/piezo_sensor/calibration_time": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/piezo_sensor/run_control": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/piezo_sensor/run_control/@description": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/piezo_sensor/value": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/piezo_sensor/value/@units": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/piezo_sensor/value_timestamp": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/volatage_sensor/calibration_time": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/volatage_sensor/run_control": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/volatage_sensor/run_control/@description": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/volatage_sensor/value": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/volatage_sensor/value/@units": "",
    "/ENTRY[entry]/experiment_insturment/scan_environment/volatage_sensor/value_timestamp": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/CHANNEL_temp[channel_temp]": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature/@units": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/calibration_time": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/calibration_time/@units": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/coefficients": "",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/coefficients/@units": "",
    "/ENTRY[entry]/experiment_insturment/hardware/model": "",
    "/ENTRY[entry]/experiment_insturment/hardware/model/@version": "",
    "/ENTRY[entry]/experiment_insturment/hardware/vendor": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/calibration_time": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/calibration_time/@units": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/coefficients": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/coefficients/@units": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_offset": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_offset/@units": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_voltage": "",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_voltage/@units": "",
    "/ENTRY[entry]/experiment_insturment/software/model": "",
    "/ENTRY[entry]/experiment_insturment/software/model/@version": "",
    "/ENTRY[entry]/experiment_insturment/software/vendor": "",
    "/ENTRY[entry]/reproducibility_indicators/current": "",
    "/ENTRY[entry]/reproducibility_indicators/current_gain": "",
    "/ENTRY[entry]/reproducibility_indicators/current_offset": "",
    "/ENTRY[entry]/reproducibility_indicators/modulation_frequency": "",
    "/ENTRY[entry]/reproducibility_indicators/modulation_signal_type": "",
    "/ENTRY[entry]/resolution_indicators/modulation_frequency": "",
    "/ENTRY[entry]/resolution_indicators/modulation_signal_type": "",
    "/ENTRY[entry]/scan_mode": "",
    "/ENTRY[entry]/start_time": "",
    "/ENTRY[entry]/start_time/@units": ""
}
# Out:
#   Cell In[216], line 25
#     "/ENTRY[entry]/experiment_instrument/scan_environment/stm_head_temp": {"raw_path":"/Temperature 1/Temperature 1",
#                                                                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
nested_dict: Dict[Any, 'nested_dict'] = dict()
def transfer_plain_template_to_nested_dict(template, nested_dict):
    def split_each_key(key, final_val, nested_dict):
        parts = key.split('/', 1)
        if len(parts) <2:
            parts.append("")
        k1, rest = parts
        k1_val = nested_dict.get(k1, None)
        if k1_val is None and rest != "":
            nested_dict[k1] = dict()
            split_each_key(rest, final_val, nested_dict[k1])
        elif rest == "":
            nested_dict[k1] = final_val
        elif isinstance(k1_val, dict):
            split_each_key(rest, final_val, k1_val)
            
    for key, value in template.items():
        parts, rest = key.split('/', 1)
        split_each_key(key=rest, final_val=value, nested_dict=nested_dict)
        
transfer_plain_template_to_nested_dict(stm_nanonis_data_feeding, nested_dict)

nested_dict_copy = {
    "ENTRY[entry]": {
        "experiment_instrument": {
            "tip_temperature": "",
            "cryo_temperature": "",
            "cryo_shield_temperature": "",
            "scan_environment": {
                "stm_head_temp": "/Temperature 1/Temperature 1",
                "cryo_bottom_temp": "",
                "cryo_shield_temp": "",
                "SCAN_CONTROL[scan_control]": {
                    "mesh_SCAN[mesh_scan]": {
                        "backward_speed_N[backward_speed_n]": "",
                        "forward_speed_N[forward_speed_n]": "",
                        "scan_speed_N[scan_speed_n]": "",
                        "channel_NAME_N[scan_name_n]": "",
                        "scan_points_N[scan_points_n]": {
                            "raw_path": "/SCAN/PIXELS"
                        },
                        "stepping_N[stepping_n]": {
                            "raw_path": "@default:1"
                        },
                        "step_size_N[step_size_n]": {
                            "raw_path": "",
                            "@units": ""
                        },
                        "scan_time": "",
                        "SCAN_DATA[scan_data]": {
                            "raw_path": "/DATA/INFO"
                        }
                    },
                    "scan_region": {
                        "scan_angle_N[scan_angle_n]": {
                            "raw_path": "/SCAN/ANGLE",
                            "@units": "@default:deg"
                        },
                        "scan_offset_N[scan_offset_n]": {
                            "raw_path": "/SCAN/OFFSET",
                            "@units": ""
                        },
                        "scan_range_N[scan_range_n]": {
                            "raw_path": "/SCAN/RANGE",
                            "@units": ""
                        }
                    },
                    "scan_time_start": "",
                    "scan_time_end": "",
                    "independent_scan_axes": {
                        "raw_path": "/SCAN/DIR"
                    },
                    "scan_resolution_N": "",
                    "accuracy_N": "",
                    "scan_type": {
                        "raw_path": "@default:mesh"
                    },
                    "scan_control_type": {
                        "raw_path": "@default:continuous"
                    }
                },
                "SENSOR[sensor]": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "independent_controllers": "",
                "measurement_sensors": "",
                "cryo_shield_temperature": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "cryo_temperature": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "tip_temperature": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                }
            },
            "LOCKIN[lockin]": {
                "modulation_frequency": "",
                "modulation_signal_type": ""
            },
            "bias_spectroscopy_environment": {
                "SENSOR[sensor]": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "independent_controllers": "",
                "measurement_sensors": ""
            },
            "current_sensor": {
                "AMPLIFIER[amplifier]": {
                    "current_gain": ""
                },
                "current": "",
                "current_calibration": {
                    "calibration_time": "",
                    "coefficients": ""
                },
                "current_offset": ""
            },
            "piezo_sensor": {
                "PIEZO_CONFIG_SPM[piezo_config_spm]": {
                    "2nd_order_corr_N[2nd_order_corr_n]": "",
                    "calibration_coeffecient_N[calibration_coeffecient_n]": "",
                    "calibration_type": "",
                    "drift_N[drift_n]": "",
                    "drift_correction_status": "",
                    "hv_gain_N[hv_gain_n]": "",
                    "tilt_N[tilt_n]": ""
                },
                "POSITIONER_SPM[positioner_spm]": {
                    "z_controller": {
                        "controller_name": "",
                        "controller_status": "",
                        "i_gain": "",
                        "p_gain": "",
                        "set_point": "",
                        "switch_off_delay": "",
                        "time_const": "",
                        "tip_lift": "",
                        "z": ""
                    }
                },
                "x": "",
                "y": "",
                "z": ""
            }
        },
        "PROCESS[process]": {
            "program": ""
        },
        "SAMPLE[sample]": {
            "name": ""
        },
        "USER[user]": {
            "address": "",
            "affiliation": "",
            "email": "",
            "name": "",
            "orcid": "",
            "telephone_number": ""
        },
        "collection_identifier": "",
        "definition": "",
        "end_time": "",
        "entry_identifier": "",
        "experiment_description": "",
        "experiment_identifier": "",
        "experiment_insturment": {
            "scan_environment": {
                "SENSOR[sensor]": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "current_sensor": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "independent_controllers": "",
                "measurement_sensors": "",
                "piezo_sensor": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                },
                "volatage_sensor": {
                    "calibration_time": "",
                    "run_control": "",
                    "value": "",
                    "value_timestamp": ""
                }
            },
            "TEMPERATURE[temperature]": {
                "CHANNEL_temp[channel_temp]": "",
                "temperature": "",
                "temperature_calibration": {
                    "calibration_time": "",
                    "coefficients": ""
                }
            },
            "hardware": {
                "model": "",
                "vendor": ""
            },
            "sample_bias_votage": {
                "bias_calibration": {
                    "calibration_time": "",
                    "coefficients": ""
                },
                "bias_offset": "",
                "bias_voltage": ""
            },
            "software": {
                "model": "",
                "vendor": ""
            }
        },
        "reproducibility_indicators": {
            "current": "",
            "current_gain": "",
            "current_offset": "",
            "modulation_frequency": "",
            "modulation_signal_type": ""
        },
        "resolution_indicators": {
            "modulation_frequency": "",
            "modulation_signal_type": ""
        },
        "scan_mode": "",
        "start_time": ""
    }
}

if not nested_dict == nested_dict_copy:
    raise ValueError("Check the nested dicts")

# %%
stm_file1 = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/test_example/Au_mica_2023_Y_A_099.sxm"
stm_file2 = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/test_example/diPAMY_Au(111)(1)/diPAMY_Au(111)/Au_mica_2023_Y_A_diPAMY_195.sxm"
# STS nanonis 5e
sts_file_5e = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/tests/data/sts_nanonis_5e/STS_nanonis_generic_5e_1.dat"

from pynxtools_stm.parsers import write_spm_raw_file_data
# raw_data = get_stm_raw_file_info(stm_file2)
write_spm_raw_file_data(sts_file_5e)
# raw_data = STM_Nanonis(stm_file1).get_SPM_metadata_dict_and_signal()
# Out:
# INFO -  STS_nanonis_generic_5e_1.txt has been created to investigate raw data structure.

# %%
# Scan_Control
import re
from pint import UnitRegistry
from typing import Optional, Dict, Tuple
import logging
ureg = UnitRegistry()

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.DEBUG, format="%(levelname)s - %(message)s")

_scientific_num_pattern = r"[-+]?[0-9]*\.?[0-9]+(?:[eE][-+]?[0-9]+)?"
conf_dict = stm_nanonis_data_feeding
data_dict = raw_data
axes = ["x", "y", "z"]

def __verify_unit(base_key=None, conf_dict=None, 
                  data_dict=None, unit=None, concept=None):
    unit_derived = None
    if unit is not None:
        unit_derived =  unit
    elif base_key:
        unit_or_path = conf_dict[f"{base_key}/@units"]
        if unit_or_path.starswith('@default:'):
            unit_derived = unit_or_path.split('@default:')[-1]
        else:
            unit_derived = data_dict.get(unit_or_path, None)
    try:
        return str(ureg(unit_derived).units)
    except Exception as e:
        # TODO: add nomad logger here
        logger.debug(f"Check the unit for nx concept {concept}.\n"
                     f"Error : {e}")
        return None
    

def __get_data_unit_and_others(self=None, data_dict=None, partial_conf_dict=None, concept_field=None)-> Tuple[str, str, Optional[dict]]:
    """Destructure the raw data, units, and other attrs.
    
    TODO: write doc test for this function
    
    Parameters:
    -----------
        data_dict : Dict[str, Any]
            The data dict that comes from the raw file. A partial example of data dict
    
            example: 
            data_dict = { 
              /SCAN/TIME" :              1.792E-1             1.792E-1
              /SCAN/RANGE :            4.000000E-9           4.000000E-9
              /SCAN/OFFSET :              -2.583985E-7         1.223062E-7
              /SCAN/ANGLE :             0.000E+0
              /SCAN/DIR : down
            }
            
        partial_conf_dict : Dict[str, Any]
            The dict that maps from nx concept field (or group especially for NXdata) to dict which explains
            raw data path, units, and other attributes (if exists).
            
            example for grp "scan_region"
            partial_conf_dict ={
                "scan_angle_N[scan_angle_n]": {
                    "raw_path": "/SCAN/ANGLE",
                    "@units": "@default:deg"
                },
                "scan_offset_N[scan_offset_n]": {
                    "raw_path": "/SCAN/OFFSET",
                },
                "scan_range_N[scan_range_n]": {
                    "raw_path": "/SCAN/RANGE",
                    "@units": "/path/to/unit/in/raw/file",
                    "@example_attr": "test_attr",
                }
            },
        concept_field : str
            The name of the concept field which is a key in partial_conf_dict
                
            example: scan_angle_N[scan_angle_n]

    Returns:
    --------
        tuple : 
            The tuple contains components like raw data string, unit string, and dict that 
            contains other attributes (if any attributes comes as a part of value dict).
            See the example below.
            
    """
     
    val_dict: dict[str: any] = partial_conf_dict[concept_field]

    raw_data = data_dict.get(val_dict.get('raw_path', None), None)
    unit_des = val_dict.get('@units', None)
    try:
        del val_dict['raw_path']
        del val_dict['@units']
    except KeyError:
        pass

    if unit_des and unit_des.startswith("@default:"):
        unit = unit_des.split("@default:")[-1]
    else:
        unit = data_dict.get(unit_des, None)
    # TODO: write a function that write other attributes in general and use that func where this function is used
    return raw_data, __verify_unit(unit=unit), val_dict

    
def __arange_axes(self=None, direction="down"):
    if direction.lower() == 'down':
        return ["-Y", "X"]
    elif direction.lower() == 'up':
        return ["Y", "X"]
    elif direction.lower() == 'right':
        return ["X", "Y"]
    elif direction.lower() == 'left':
        return ["-X", "Y"]


def construct_scan_control_grp(template, 
                           partial_conf_dict, 
                           parent_path: str, 
                           data_dict, 
                           group_name='scan_control', 
                           layer_dict=None):
    global gbl_scan_points, gbl_scan_ranges
    # gbl_scan_ranges = None
    # gbl_scan_points = None
    def construct_scan_region_grp(template, 
                                  partial_conf_dict, 
                                  parent_path: str, 
                                  data_dict, 
                                  group_name='scan_region'):
        scan_angle = "scan_offset_N[scan_offset_n]"
        
        scan_angles, unit, _ = __get_data_unit_and_others(data_dict=data_dict, 
                                                          partial_conf_dict=partial_conf_dict, 
                                                          concept_field=scan_angle) 
        scan_angles = re.findall(_scientific_num_pattern, scan_angles)
        for ind, ang in enumerate(scan_angles):
            template[f"{parent_path}/{group_name}/scan_offset_{axes[ind]}"] = ang
            template[f"{parent_path}/{group_name}/scan_offset_{axes[ind]}/@units"] = unit  
            
        
        # scan range
        scan_range = "scan_range_N[scan_range_n]"
        scan_ranges, unit, _ = __get_data_unit_and_others(data_dict=data_dict, 
                                                 partial_conf_dict=partial_conf_dict,
                                                 concept_field=scan_range)
        global gbl_scan_ranges
        gbl_scan_ranges = re.findall(_scientific_num_pattern, scan_ranges)
        if gbl_scan_ranges:
            gbl_scan_ranges = [float(x) for x in gbl_scan_ranges]
    
        for ind, rng in enumerate(gbl_scan_ranges):
            template[f"{parent_path}/{group_name}/scan_range_{axes[ind]}"] = rng
            template[f"{parent_path}/{group_name}/scan_range_{axes[ind]}/@units"] = unit
    
    def construct_scan_pattern_grp(template, 
                                  partial_conf_dict, 
                                  parent_path: str, 
                                  data_dict, 
                                  group_name='scan_mesh', 
                                  layer_dict=None):
        """To construct the scan pattern like scan_mesh, scan_spiral (group) etc."""
        
        # scan_point fields            
        scan_point = "scan_points_N[scan_points_n]"
        
        scan_points, unit, _ = __get_data_unit_and_others(data_dict=data_dict, 
                                                          partial_conf_dict=partial_conf_dict, 
                                                          concept_field=scan_point) 
        global gbl_scan_points, gbl_scan_ranges
        gbl_scan_points = re.findall(_scientific_num_pattern, scan_points)
        if gbl_scan_points:
            gbl_scan_points = [float(x) for x in gbl_scan_points]
        for ind, point in enumerate(gbl_scan_points):
            template[f"{parent_path}/{group_name}/scan_points_{axes[ind]}"] = point
        # step_size
        if len(gbl_scan_points) == len(gbl_scan_ranges):
            for find, (rng, pnt) in enumerate(zip(gbl_scan_ranges, gbl_scan_points)):
                template[f"{parent_path}/{group_name}/step_size_{axes[ind]}"] = rng / pnt
                template[f"{parent_path}/{group_name}/step_size_{axes[ind]}/@units"] = unit
    
    # find independent_scan_axes
    # independent_axes = "/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/independent_scan_axes"
    independent_axes = "independent_scan_axes"
    direction, _, _ = __get_data_unit_and_others(data_dict=data_dict, 
                                                       partial_conf_dict= partial_conf_dict, 
                                                       concept_field=independent_axes)
    template[f"{parent_path}/{group_name}/independent_scan_axes"] = __arange_axes(direction.strip())
    scan_region_grp = 'scan_region'
    scan_region_dict = partial_conf_dict.get(scan_region_grp, None)
    if scan_region_dict is not None:
        construct_scan_region_grp(template,
                                  partial_conf_dict=scan_region_dict,
                                  parent_path=f"{parent_path}/{group_name}",
                                  data_dict=data_dict,
                                  group_name=scan_region_grp)
    scan_pattern_grp = 'mesh_SCAN[mesh_scan]'
    scan_pattern_dict = partial_conf_dict.get(scan_pattern_grp, None)
    if scan_pattern_dict is not None:
        construct_scan_pattern_grp(template,
                                   partial_conf_dict=scan_pattern_dict,
                                   parent_path=f"{parent_path}/{group_name}",
                                   data_dict=data_dict,
                                   group_name=scan_pattern_grp)

# %%
from pynxtools_stm import get_stm_raw_file_info
from pynxtools_stm.stm_file_parser import STM_Nanonis
from pynxtools.dataconverter.template import Template
from pynxtools.dataconverter.helpers import generate_template_from_nxdl, get_nxdl_root_and_path 
template = Template()

def create_nexus_file():
    app_def = "NXstm"
    out_file = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/pynxtools_stm/file_parsers/bruker/out.nxs"
    input_file = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/test_example/AFM_from_Carlos/A151216.123306-02602.sxm"
   # raw_data = get_stm_raw_file_info(stm_file2)
    
    raw_data = STM_Nanonis(stm_file1).get_SPM_metadata_dict_and_signal()
    root, nxdl_path = get_nxdl_root_and_path(app_def)
    generate_template_from_nxdl(root, nxdl_name=app_def, template=template)
    scan_control_dict = nested_dict_copy['ENTRY[entry]']['experiment_instrument']['scan_environment']["SCAN_CONTROL[scan_control]"]
    construct_scan_control_grp(template, 
                               partial_conf_dict= scan_control_dict, 
                               parent_path = '/ENTRY[entry]/experiment_instrument/scan_environment', 
                               data_dict = raw_data, 
                               group_name='SCAN_CONTROL[scan_control]', 
                               layer_dict=None)
create_nexus_file()

# clean the template
filter_template = Template()
for key, val in template.items():
    if val is not None or val == "":
        filter_template[key] = val

# %%
filter_template
# Out:
# {'/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/independent_scan_axes': ['-Y', 'X'], '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_points_x': 256.0, '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_points_y': 256.0, '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/step_size_y': 1.5625e-11, '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/step_size_y/@units': 'dimensionless', '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset_x': '-2.583985E-7', '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset_x/@units': 'dimensionless', '/ENTRY[entry]/experiment_instrument/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offse
# ...

# %%
nxdl = "NXstm"
reader = "spm"
input_file = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/test_example/AFM_from_Carlos/A151216.123306-02602.sxm"

# %%
# !dataconverter --nxdl nxdl --reader reader input_file
# Out:
# Usage: dataconverter convert [OPTIONS] [FILES]...
# Try 'dataconverter convert --help' for help.
#
# Error: Invalid value for '--reader': 'reader' is not one of 'example', 'json_map', 'json_yml', 'sts'.

# %%
L
