# %%
AFM_template = {
    "/ENTRY[entry]/INSTRUMENT[instrument]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/CANTILEVER_SPM[cantilever_spm]/": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/CANTILEVER_SPM[cantilever_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/CANTILEVER_SPM[cantilever_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/CANTILEVER_SPM[cantilever_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor/calibration_time": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor/value": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor/value/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor[xy_piezo_sensor]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor[xy_piezo_sensor]/calibration_time": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor[xy_piezo_sensor]/value": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/XY_piezo_sensor[xy_piezo_sensor]/value/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/height_piezo_sensor": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/height_piezo_sensor/calibration_time": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/height_piezo_sensor/value": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/height_piezo_sensor/value/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/independent_controllers": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/measurement_sensors": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/tip_temperature": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/tip_temperature/calibration_time": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/tip_temperature/value": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/tip_temperature/value/@units": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/XY_piezo_sensor[xy_piezo_sensor]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/XY_piezo_sensor[xy_piezo_sensor]/PIEZO_CONFIG_SPM[piezo_config_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/XY_piezo_sensor[xy_piezo_sensor]/POSITIONER_SPM[positioner_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/XY_piezo_sensor[xy_piezo_sensor]/piezo_material": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/height_piezo_sensor": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/height_piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/height_piezo_sensor/POSITIONER_SPM[positioner_spm]": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/height_piezo_sensor/piezo_material": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/photo_detector": "None",
    "/ENTRY[entry]/INSTRUMENT[instrument]/tip_temperature": "None",
    # Note: topography data will go to the plot
    # Currrent sensor: 
    # TODO: rename the instrument for AFM app def to experiment_instrument
    "/ENTRY[entry]/experiment_instrument/current_sensor/current_sensitivity": "/*Ciao scan list/AFM Current Sensitivity",
    "/ENTRY[entry]/definition": "None",
    "/ENTRY[entry]/definition/@version": "None",
    "/ENTRY[entry]/scan_mode": "None"
}

SPM_template = {
    "/ENTRY[entry]/SAMPLE[sample]": "None",
    "/ENTRY[entry]/SAMPLE[sample]/name": "None",
    "/ENTRY[entry]/SAMPLE[sample]/sample_environment": "None",
    "/ENTRY[entry]/SAMPLE[sample]/sample_environment/sample_bias_voltage": "None",
    "/ENTRY[entry]/definition": "None",
    "/ENTRY[entry]/definition/@version": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SCAN_CONTROL[scan_control]": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/calibration_time": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/value": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/value/@units": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/independent_controllers": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/measurement_sensors": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/calibration_time": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/value": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/value/@units": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/calibration_time": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/value": "None",
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/value/@units": "None",
    "/ENTRY[entry]/experiment_insturment/LOCKIN[lockin]": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/CHANNEL_temp[channel_temp]": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature/@units": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/calibration_time": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/calibration_time/@units": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/coefficients": "None",
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/coefficients/@units": "None",
    "/ENTRY[entry]/experiment_insturment/current_sensor": "None",
    "/ENTRY[entry]/experiment_insturment/current_sensor/AMPLIFIER[amplifier]": "None",
    "/ENTRY[entry]/experiment_insturment/hardware/model": "None",
    "/ENTRY[entry]/experiment_insturment/hardware/model/@version": "None",
    "/ENTRY[entry]/experiment_insturment/hardware/vendor": "None",
    "/ENTRY[entry]/experiment_insturment/piezo_sensor": "None",
    "/ENTRY[entry]/experiment_insturment/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]": "None",
    "/ENTRY[entry]/experiment_insturment/piezo_sensor/POSITIONER_SPM[positioner_spm]": "None",
    "/ENTRY[entry]/experiment_insturment/piezo_sensor/piezo_material": "None",
    "/ENTRY[entry]/experiment_insturment/real_time_controller": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/calibration_time": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/calibration_time/@units": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/coefficients": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/coefficients/@units": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_offset": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_offset/@units": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_voltage": "None",
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_voltage/@units": "None",
    "/ENTRY[entry]/experiment_insturment/software/model": "None",
    "/ENTRY[entry]/experiment_insturment/software/model/@version": "None",
    "/ENTRY[entry]/experiment_insturment/software/vendor": "None",
    "/ENTRY[entry]/experiment_insturment/volatage_sensor": "None",
    "/ENTRY[entry]/experiment_insturment/volatage_sensor/AMPLIFIER[amplifier]": "None",
    "/ENTRY[entry]/reproducibility_indicators": "None",
    "/ENTRY[entry]/resolution_indicators": "None",
    "/ENTRY[entry]/scan_mode": "None"
}

STM_template = {
    "/@HDF5_Version[@hdf5_version]": null,
    "/@HDF_version[@hdf_version]": null,
    "/@NX_class[@nx_class]": null,
    "/@NeXus_repository[@nexus_repository]": null,
    "/@NeXus_version[@nexus_version]": null,
    "/@XML_version[@xml_version]": null,
    "/@creator": null,
    "/@creator_version": null,
    "/@default": null,
    "/@file_name": null,
    "/@file_time": null,
    "/@file_update_time": null,
    "/@h5py_version": null,
    "/@partial": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/SENSOR[sensor]/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/SENSOR[sensor]/run_control": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/SENSOR[sensor]/run_control/@description": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/SENSOR[sensor]/value": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/SENSOR[sensor]/value/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/SENSOR[sensor]/value_timestamp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/independent_controllers": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/ENVIRONMENT[environment]/measurement_sensors": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/LOCKIN[lockin]/modulation_frequency": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/LOCKIN[lockin]/modulation_frequency/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/LOCKIN[lockin]/modulation_signal_type": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/LOCKIN[lockin]/modulation_signal_type/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/SENSOR[sensor]/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/SENSOR[sensor]/run_control": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/SENSOR[sensor]/run_control/@description": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/SENSOR[sensor]/value": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/SENSOR[sensor]/value/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/SENSOR[sensor]/value_timestamp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/independent_controllers": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/bias_spectroscopy_environment/measurement_sensors": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/AMPLIFIER[amplifier]/current_gain": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/AMPLIFIER[amplifier]/current_gain/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current_calibration/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current_calibration/calibration_time/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current_calibration/coefficients": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current_calibration/coefficients/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current_offset": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/current_sensor/current_offset/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/2nd_order_corr_N[2nd_order_corr_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/2nd_order_corr_N[2nd_order_corr_n]/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_coeffecient_N[calibration_coeffecient_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_coeffecient_N[calibration_coeffecient_n]/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/calibration_type": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/drift_N[drift_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/drift_correction_status": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/hv_gain_N[hv_gain_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/tilt_N[tilt_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/PIEZO_CONFIG_SPM[piezo_config_spm]/tilt_N[tilt_n]/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/controller_name": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/controller_status": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/i_gain": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/i_gain/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/p_gain": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/p_gain/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/set_point": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/set_point/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/switch_off_delay": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/switch_off_delay/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/time_const": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/time_const/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/tip_lift": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/tip_lift/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/POSITIONER_SPM[positioner_spm]/z_controller/z": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/x": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/x/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/y": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/y/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/z": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/piezo_sensor/z/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/backward_speed_N[backward_speed_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/backward_speed_N[backward_speed_n]/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/forward_speed_N[forward_speed_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/forward_speed_N[forward_speed_n]/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_speed": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_speed/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/mesh_SCAN[mesh_scan]/scan_time/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_angle_N[scan_angle_n]": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_angle_N[scan_angle_n]/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_offset/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_range": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_region/scan_range/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SCAN_CONTROL[scan_control]/scan_type": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SENSOR[sensor]/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SENSOR[sensor]/run_control": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SENSOR[sensor]/run_control/@description": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SENSOR[sensor]/value": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SENSOR[sensor]/value/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/SENSOR[sensor]/value_timestamp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_bottom_temp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_bottom_temp/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temp/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temperature/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temperature/run_control": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temperature/run_control/@description": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temperature/value": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temperature/value/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_shield_temperature/value_timestamp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_temperature/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_temperature/run_control": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_temperature/run_control/@description": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_temperature/value": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_temperature/value/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/cryo_temperature/value_timestamp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/independent_controllers": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/measurement_sensors": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/stm_head_temp": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/stm_head_temp/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/tip_temperature/calibration_time": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/tip_temperature/run_control": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/tip_temperature/run_control/@description": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/tip_temperature/value": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/tip_temperature/value/@units": null,
    "/ENTRY[entry]/INSTRUMENT[instrument]/scan_environment/tip_temperature/value_timestamp": null,
    "/ENTRY[entry]/PROCESS[process]/program": null,
    "/ENTRY[entry]/PROCESS[process]/program/@program_url": null,
    "/ENTRY[entry]/PROCESS[process]/program/@version": null,
    "/ENTRY[entry]/SAMPLE[sample]/name": null,
    "/ENTRY[entry]/USER[user]/address": null,
    "/ENTRY[entry]/USER[user]/affiliation": null,
    "/ENTRY[entry]/USER[user]/email": null,
    "/ENTRY[entry]/USER[user]/name": null,
    "/ENTRY[entry]/USER[user]/orcid": null,
    "/ENTRY[entry]/USER[user]/telephone_number": null,
    "/ENTRY[entry]/collection_identifier": null,
    "/ENTRY[entry]/definition": null,
    "/ENTRY[entry]/definition/@version": null,
    "/ENTRY[entry]/end_time": null,
    "/ENTRY[entry]/end_time/@units": null,
    "/ENTRY[entry]/entry_identifier": null,
    "/ENTRY[entry]/experiment_description": null,
    "/ENTRY[entry]/experiment_identifier": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SENSOR[sensor]/calibration_time": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SENSOR[sensor]/run_control": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SENSOR[sensor]/run_control/@description": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SENSOR[sensor]/value": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SENSOR[sensor]/value/@units": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/SENSOR[sensor]/value_timestamp": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/calibration_time": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/run_control": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/run_control/@description": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/value": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/value/@units": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/current_sensor/value_timestamp": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/independent_controllers": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/measurement_sensors": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/calibration_time": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/run_control": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/run_control/@description": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/value": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/value/@units": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/piezo_sensor/value_timestamp": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/calibration_time": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/run_control": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/run_control/@description": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/value": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/value/@units": null,
    "/ENTRY[entry]/experiment_insturment/ENVIRONMENT[environment]/volatage_sensor/value_timestamp": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/CHANNEL_temp[channel_temp]": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature/@units": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/calibration_time": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/calibration_time/@units": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/coefficients": null,
    "/ENTRY[entry]/experiment_insturment/TEMPERATURE[temperature]/temperature_calibration/coefficients/@units": null,
    "/ENTRY[entry]/experiment_insturment/hardware/model": null,
    "/ENTRY[entry]/experiment_insturment/hardware/model/@version": null,
    "/ENTRY[entry]/experiment_insturment/hardware/vendor": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/calibration_time": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/calibration_time/@units": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/coefficients": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_calibration/coefficients/@units": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_offset": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_offset/@units": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_voltage": null,
    "/ENTRY[entry]/experiment_insturment/sample_bias_votage/bias_voltage/@units": null,
    "/ENTRY[entry]/experiment_insturment/software/model": null,
    "/ENTRY[entry]/experiment_insturment/software/model/@version": null,
    "/ENTRY[entry]/experiment_insturment/software/vendor": null,
    "/ENTRY[entry]/reproducibility_indicators/current": null,
    "/ENTRY[entry]/reproducibility_indicators/current_gain": null,
    "/ENTRY[entry]/reproducibility_indicators/current_offset": null,
    "/ENTRY[entry]/reproducibility_indicators/modulation_frequency": null,
    "/ENTRY[entry]/reproducibility_indicators/modulation_signal_type": null,
    "/ENTRY[entry]/resolution_indicators/modulation_frequency": null,
    "/ENTRY[entry]/resolution_indicators/modulation_signal_type": null,
    "/ENTRY[entry]/scan_mode": null,
    "/ENTRY[entry]/start_time": null,
    "/ENTRY[entry]/start_time/@units": null
}

# %%
import os


file = "/home/rubel/NOMAD-FAIRmat/GH/pynxtools-stm/tests/new_data/SPM_from_tamas/VGEP-15m-.0_00000.spm"

os.path.isfile(file)
# Out:
# True

# %%
from pynxtools_stm.file_parsers.bruker.brukerSPM import BrukerSPM
import numpy as np

# %%
bkr = BrukerSPM(file)

# %%
metadata = bkr.parsed_data
metadata_list = [(key, val) for key, val in metadata.items()]
layer_list = bkr.layers # 8 layers
scanner_list = bkr.scanners # 1 scanners
channel_list = bkr.list_channels()
# Out:
# Channels
# ...
# @2:Image Data: S [ZSensor] "Height Sensor"
# @2:Image Data: S [AmplitudeError] "Amplitude Error"
# @2:Image Data: S [Phase] "Phase"
# @2:Image Data: S [ZSensor] "Height Sensor"
# @2:Image Data: S [AmplitudeError] "Amplitude Error"
# @2:Image Data: S [Phase] "Phase"
# @2:Image Data: S [AmplitudeActual] "Amplitude"
# @2:Image Data: S [DeflectionActual] "TM Deflection"

# %%
# len(scanner_list[0].items())
layer_list[-1]#, layer_list[1], layer_list[2]
# Out:
# {b'Data offset': [b'7420992'],
#  b'Data length': [b'1048576'],
#  b'Bytes/pixel': [b'2'],
#  b'Start context': [b'OL'],
#  b'Data type': [b'AFM'],
#  b'Plane fit': [b'161 -43 14.25 2'],
#  b'Frame direction': [b'Down'],
#  b'Capture start line': [b'0'],
#  b'Color Table Index': [b'12'],
#  b'Relative frame time': [b'5203.42'],
#  b'Invalid Data Flag': [b'None'],
#  b'Invalid Data Fill': [b'None'],
#  b'Samps/line': [b'512'],
#  b'Number of lines': [b'512'],
#  b'Aspect Ratio': [b'1:1'],
#  b'Scan Size': [b'20 20 ~m'],
#  b'Scan Line': [b'Main'],
#  b'Line Direction': [b'Retrace'],
#  b'Highpass': [b'0'],
#  b'Lowpass': [b'0'],
#  b'Realtime Planefit': [b'Line'],
#  b'Offline Planefit': [b'Full'],
#  b'Valid data start X': [b'0'],
#  b'Valid data start Y': [b'0'],
#  b'Valid data len X': [b'512'],
#  b'Valid data len Y': [b'512'],
#  b'Tip x width correction factor': [b'1'],
#  b'Tip y width correction factor': [b'1'],
#  b'Tip x width correction factor sigma': [b'1'],
# ...

# %%
# sensitivity unit
unit_tuple_list = list(filter(lambda x: 'Metric' in x[0].decode().lower(), scanner_list[0].items()))

# %%
# Out:
# []

# %%
bkr.get_channel_data(channel="Height Sensor")#['BIN'])

# %%
scanner_list = list(filter(lambda x: ('Scanner list/' in x[0]), metadata_list))
ciao_scan_list = list(filter(lambda x: ('Ciao scan list' in x[0]), metadata_list))

image_list_N = list(filter(lambda x: '/*Ciao image list/' in x[0], metadata_list))
len(image_list_N)
# Out:
# 34

# %%
metadata
# Out:
# {'/Version': '0x09400105',
#  '/Date': '04:22:38 PM Mon Jul 10 2023',
#  '/Start context': 'OL2BIG',
#  '/Data length': '80960',
#  '/User Rating': '0',
#  '/Engage X Pos': '-19783.4 um',
#  '/Engage Y Pos': '-42151.3 um',
#  '/*Equipment list/Description': 'Dimension Icon',
#  '/*Equipment list/Vision': 'uEye UI148xLE-C #1',
#  '/*Equipment list/Scanner file': '1b818.scn',
#  '/*Scanner list/Scanner type': 'Dim 4000',
#  '/*Scanner list/Head Type': 'SG',
#  '/*Scanner list/Serial Number': '1b818',
#  '/*Scanner list/Piezo size': 'G',
#  '/*Scanner list/File name': '1b818.scn',
#  '/*Scanner list/Retracted offset der': '-3.6663',
#  '/*Scanner list/Extended offset der': '4.0997',
#  '/*Scanner list/Allow rotation': 'Allow',
#  '/*Scanner list/Piezo cal': '440',
#  '/*Scanner list/X sensitivity': '144.78',
#  '/*Scanner list/X derate': '0.178',
#  '/*Scanner list/X mag': '0.95',
#  '/*Scanner list/X mag1': '0.75',
#  '/*Scanner list/X arg': '2.5',
# ...
